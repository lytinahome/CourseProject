# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
#import cudf 
import numpy as np

# %%
data = pd.read_csv("./merged_DishInText.csv")

# %%
data
# Out:
#          Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0                 0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1                 1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2                 5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3                 7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# 4                 8  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# ...             ...                     ...    ...     ...    ...   ...
# 2445689     5126133  hn9Toz3s-Ei3uZPt7esExA    5.0       0      0     0
# 2445690     5126134  hn9Toz3s-Ei3uZPt7esExA    4.0       0      0     0
# 2445691     5126135  hn9Toz3s-Ei3uZPt7esExA    5.0       2      0     2
# 2445692     5126137  hn9Toz3s-Ei3uZPt7esExA    5.0       1      1     1
# 2445693     5126138  hn9Toz3s-Ei3uZPt7esExA    4.0       0      0     0
#
#                        DishInText
# 0                        {'rice'}
# 1                        {'rice'}
# 2             {'english', 'rice'}
# 3                       {'bread'}
# 4                        {'rice'}
# ...                           ...
# 2445689          {'rice', 'pita'}
# 2445690                 {'bread'}
# 2445691  {'rice', 'naan', 'pita'}
# 2445692                  {'pita'}
# 2445693          {'rice', 'pita'}
#
# [2445694 rows x 7 columns]

# %%
data['weight'] = 1 + (data['useful'] + 0.5 * data['funny'] + 0.5 * data['cool'])**(1/3)

# %%
data['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
data['weighted_score'] = (data['stars'] - 3) * data['weight']

# %%
data['weighted_score'].hist()
# Out:
# <AxesSubplot:>

# %%
all_business = set(data['business_id'])

# %%
len(data), len(all_business)
# Out:
# (2445694, 63631)

# %%
import re
data["expanded_DishInText"] = data['DishInText'].apply(lambda x: (re.findall(r"'(.*?)'", x)))

# %%
expanded_data = data.explode('expanded_DishInText', ignore_index = True)

# %%
data.loc[data['business_id'] == 'MTSW4McQd7CbVtyjqoe9mw', :]
# Out:
#     Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0            0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1            1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2            5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3            7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# 4            8  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 5            9  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 6           10  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 7           11  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 8           20  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 9           21  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 10          22  MTSW4McQd7CbVtyjqoe9mw    3.0       0      0     0
# 11          24  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 12          25  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 13          28  MTSW4McQd7CbVtyjqoe9mw    3.0       6      3     3
# 14          29  MTSW4McQd7CbVtyjqoe9mw    4.0       6      0     2
# 15          32  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 16          33  MTSW4McQd7CbVtyjqoe9mw    5.0       1      1     1
# 17          34  MTSW4McQd7CbVtyjqoe9mw    3.0       2      0     1
# 18          35  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 19          39  MTSW4McQd7CbVtyjqoe9mw    4.0       2      0     1
# 20          41  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 21          43  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 22          44  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 23          46  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 24          49  MTSW4McQd7CbVtyjqoe9mw    3.0       1      0     1
# 25          50  MTSW4McQd7CbVtyjqoe9mw    4.0       3      3     3
# 26          51  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     1
# 27          52  MTSW4McQd7CbVtyjqoe9mw    3.0       0      0     0
# 28          54  MTSW4McQd7CbVtyjqoe9mw    1.0       4      3     1
# 29          56  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 30          58  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 31          59  MTSW4McQd7CbVtyjqoe9mw    4.0       2      1     0
# 32          63  MTSW4McQd7CbVtyjqoe9mw    3.0       1      0     0
# 33          64  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 34          65  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 35          68  MTSW4McQd7CbVtyjqoe9mw    5.0       2      0     3
# 36          71  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 37          72  MTSW4McQd7CbVtyjqoe9mw    1.0       0      0     0
# 38          73  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 39          74  MTSW4McQd7CbVtyjqoe9mw    4.0       1      1     1
# 40          75  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 41          76  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 42          78  MTSW4McQd7CbVtyjqoe9mw    5.0       2      0     1
# 43          79  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     5
# 44          82  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 45          83  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 46          84  MTSW4McQd7CbVtyjqoe9mw    5.0      35     14    26
# 47          85  MTSW4McQd7CbVtyjqoe9mw    2.0       2      2     1
#
#                           DishInText    weight  weighted_score  \
# 0                           {'rice'}  1.793701        1.793701
# 1                           {'rice'}  2.650964        2.650964
# 2                {'english', 'rice'}  2.000000        2.000000
# 3                          {'bread'}  3.154435        3.154435
# 4                           {'rice'}  1.000000        1.000000
# 5              {'chocolate', 'rice'}  1.000000        1.000000
# 6                          {'bread'}  1.000000        1.000000
# 7            {'soy milk', 'hot dog'}  1.793701        1.793701
# 8                           {'rice'}  2.000000        4.000000
# 9                        {'english'}  1.000000        2.000000
# 10                          {'rice'}  1.000000        0.000000
# 11             {'chocolate', 'rice'}  2.000000        4.000000
# 12                         {'bread'}  1.000000        1.000000
# 13                         {'bread'}  3.080084        0.000000
# 14   {'chocolate', 'curry', 'bread'}  2.912931        2.912931
# 15             {'croissant', 'rice'}  1.000000        2.000000
# 16                   {'rice', 'dal'}  2.259921        4.519842
# 17               {'rice', 'hot dog'}  2.357209        0.000000
# 18                          {'rice'}  2.000000        2.000000
# 19                         {'curry'}  2.357209        2.357209
# 20                          {'rice'}  2.000000        4.000000
# 21                          {'rice'}  2.000000        4.000000
# 22                          {'pita'}  1.000000        1.000000
# 23  {'english', 'rice', 'chocolate'}  1.000000        1.000000
# 24                       {'english'}  2.144714        0.000000
# 25                          {'rice'}  2.817121        2.817121
# 26               {'english', 'rice'}  1.793701        3.587401
# 27                          {'rice'}  1.000000        0.000000
# 28                         {'ploye'}  2.817121       -5.634241
# 29                         {'bread'}  2.000000        2.000000
# 30                       {'english'}  1.000000        2.000000
# 31             {'rice', 'dumplings'}  2.357209        2.357209
# 32             {'char siu', 'bread'}  2.000000        0.000000
# 33                     {'dumplings'}  1.000000        2.000000
# 34                          {'rice'}  1.000000        1.000000
# 35                         {'bread'}  2.518294        5.036589
# 36                         {'bread'}  1.000000        2.000000
# 37                     {'taro cake'}  1.000000       -2.000000
# 38                          {'rice'}  2.000000        4.000000
# 39                         {'bread'}  2.259921        2.259921
# 40                          {'rice'}  2.000000        4.000000
# 41                         {'bread'}  1.000000        2.000000
# 42                          {'rice'}  2.357209        4.714418
# 43                         {'swiss'}  2.357209        4.714418
# 44              {'mooncake', 'rice'}  2.000000        4.000000
# 45                {'baozi', 'bread'}  2.000000        2.000000
# 46                          {'rice'}  4.802952        9.605905
# 47                          {'rice'}  2.518294       -2.518294
#
#            expanded_DishInText
# 0                       [rice]
# 1                       [rice]
# 2              [english, rice]
# 3                      [bread]
# 4                       [rice]
# 5            [chocolate, rice]
# 6                      [bread]
# 7          [soy milk, hot dog]
# 8                       [rice]
# 9                    [english]
# 10                      [rice]
# 11           [chocolate, rice]
# 12                     [bread]
# 13                     [bread]
# 14   [chocolate, curry, bread]
# 15           [croissant, rice]
# 16                 [rice, dal]
# 17             [rice, hot dog]
# 18                      [rice]
# 19                     [curry]
# 20                      [rice]
# 21                      [rice]
# 22                      [pita]
# 23  [english, rice, chocolate]
# 24                   [english]
# 25                      [rice]
# 26             [english, rice]
# 27                      [rice]
# 28                     [ploye]
# 29                     [bread]
# 30                   [english]
# 31           [rice, dumplings]
# 32           [char siu, bread]
# 33                 [dumplings]
# 34                      [rice]
# 35                     [bread]
# 36                     [bread]
# 37                 [taro cake]
# 38                      [rice]
# 39                     [bread]
# 40                      [rice]
# 41                     [bread]
# 42                      [rice]
# 43                     [swiss]
# 44            [mooncake, rice]
# 45              [baozi, bread]
# 46                      [rice]
# 47                      [rice]

# %%
expanded_data.loc[expanded_data['business_id'] == 'MTSW4McQd7CbVtyjqoe9mw', :]
# Out:
#     Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0            0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1            1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2            5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3            5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 4            7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# ..         ...                     ...    ...     ...    ...   ...
# 59          82  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 60          83  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 61          83  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 62          84  MTSW4McQd7CbVtyjqoe9mw    5.0      35     14    26
# 63          85  MTSW4McQd7CbVtyjqoe9mw    2.0       2      2     1
#
#               DishInText    weight  weighted_score expanded_DishInText
# 0               {'rice'}  1.793701        1.793701                rice
# 1               {'rice'}  2.650964        2.650964                rice
# 2    {'english', 'rice'}  2.000000        2.000000             english
# 3    {'english', 'rice'}  2.000000        2.000000                rice
# 4              {'bread'}  3.154435        3.154435               bread
# ..                   ...       ...             ...                 ...
# 59  {'mooncake', 'rice'}  2.000000        4.000000                rice
# 60    {'baozi', 'bread'}  2.000000        2.000000               baozi
# 61    {'baozi', 'bread'}  2.000000        2.000000               bread
# 62              {'rice'}  4.802952        9.605905                rice
# 63              {'rice'}  2.518294       -2.518294                rice
#
# [64 rows x 10 columns]

# %%
print(len(set(expanded_data.loc[expanded_data['business_id'] == 'MTSW4McQd7CbVtyjqoe9mw', :]["expanded_DishInText"])))
# Out:
# 17

# %%
def OneRestScore(df_one_rest: pd.DataFrame, buz_id: str):
  dish_candidate = set(df_one_rest.loc[df_one_rest['business_id'] == buz_id, 'expanded_DishInText'])
  dish_dict = {}
  for dish in dish_candidate:
      score = df_one_rest.loc[(df_one_rest['business_id'] == buz_id) 
                                & (df_one_rest['expanded_DishInText'] == dish), 'weighted_score']
      dish_dict[dish] = score.mean()
  return dish_dict

# %%
def AllRestScore(df: pd.DataFrame):
  start = 0 
  end = 0
  count = 0
  buz_dict = {}
  while end < len(df)-1  :
    count += 1
    while (df.at[start, "business_id"] == df.at[end, "business_id"]) and end<len(df)-1:
      end +=1
    buz = df.at[start, "business_id"]
    temp_df = df[start:end]
    buz_dict[buz] = OneRestScore(temp_df, buz)
    start = end
    #dishset = set(df.loc[start:end, "expanded_DishInText"])
    #df.loc[start:end, "dishset"] = str(dishset)
    
    #print(df.at[end, "business_id"], str(dishset))
    if count%1000 ==0:
      print(count)
  return buz_dict

# %%
score = AllRestScore(expanded_data)
print(len(score['MTSW4McQd7CbVtyjqoe9mw']))
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 17

# %%
score["hn9Toz3s-Ei3uZPt7esExA"]
# Out:
# {'naan': 4.884499140614817,
#  'rice': 2.7389747792693924,
#  'boule': -2.0,
#  'bread': 1.0,
#  'pita': 3.4426364784217878}

# %%
score_table = pd.DataFrame.from_dict(score, orient='index')

# %%
score_table.head()
print(len(score_table))
# Out:
# 63631

# %%
score_table.to_csv("./score_table_mean.csv")
