# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./merged_DishInText.csv")

# %%
data.head()
# Out:
#    Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0           0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1           1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2           5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3           7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# 4           8  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
#
#             DishInText
# 0             {'rice'}
# 1             {'rice'}
# 2  {'english', 'rice'}
# 3            {'bread'}
# 4             {'rice'}

# %%
data
# Out:
#          Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0                 0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1                 1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2                 5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3                 7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# 4                 8  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# ...             ...                     ...    ...     ...    ...   ...
# 2445689     5126133  hn9Toz3s-Ei3uZPt7esExA    5.0       0      0     0
# 2445690     5126134  hn9Toz3s-Ei3uZPt7esExA    4.0       0      0     0
# 2445691     5126135  hn9Toz3s-Ei3uZPt7esExA    5.0       2      0     2
# 2445692     5126137  hn9Toz3s-Ei3uZPt7esExA    5.0       1      1     1
# 2445693     5126138  hn9Toz3s-Ei3uZPt7esExA    4.0       0      0     0
#
#                        DishInText
# 0                        {'rice'}
# 1                        {'rice'}
# 2             {'english', 'rice'}
# 3                       {'bread'}
# 4                        {'rice'}
# ...                           ...
# 2445689          {'rice', 'pita'}
# 2445690                 {'bread'}
# 2445691  {'rice', 'naan', 'pita'}
# 2445692                  {'pita'}
# 2445693          {'rice', 'pita'}
#
# [2445694 rows x 7 columns]

# %%
data.loc[data['business_id'] == 'MTSW4McQd7CbVtyjqoe9mw', :]
# Out:
#     Unnamed: 0             business_id  stars  useful  funny  cool  \
# 0            0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 1            1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2
# 2            5  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 3            7  MTSW4McQd7CbVtyjqoe9mw    4.0       3      4    10
# 4            8  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 5            9  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 6           10  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 7           11  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1
# 8           20  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 9           21  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 10          22  MTSW4McQd7CbVtyjqoe9mw    3.0       0      0     0
# 11          24  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 12          25  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 13          28  MTSW4McQd7CbVtyjqoe9mw    3.0       6      3     3
# 14          29  MTSW4McQd7CbVtyjqoe9mw    4.0       6      0     2
# 15          32  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 16          33  MTSW4McQd7CbVtyjqoe9mw    5.0       1      1     1
# 17          34  MTSW4McQd7CbVtyjqoe9mw    3.0       2      0     1
# 18          35  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 19          39  MTSW4McQd7CbVtyjqoe9mw    4.0       2      0     1
# 20          41  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 21          43  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 22          44  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 23          46  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 24          49  MTSW4McQd7CbVtyjqoe9mw    3.0       1      0     1
# 25          50  MTSW4McQd7CbVtyjqoe9mw    4.0       3      3     3
# 26          51  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     1
# 27          52  MTSW4McQd7CbVtyjqoe9mw    3.0       0      0     0
# 28          54  MTSW4McQd7CbVtyjqoe9mw    1.0       4      3     1
# 29          56  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 30          58  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 31          59  MTSW4McQd7CbVtyjqoe9mw    4.0       2      1     0
# 32          63  MTSW4McQd7CbVtyjqoe9mw    3.0       1      0     0
# 33          64  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 34          65  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     0
# 35          68  MTSW4McQd7CbVtyjqoe9mw    5.0       2      0     3
# 36          71  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 37          72  MTSW4McQd7CbVtyjqoe9mw    1.0       0      0     0
# 38          73  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 39          74  MTSW4McQd7CbVtyjqoe9mw    4.0       1      1     1
# 40          75  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 41          76  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     0
# 42          78  MTSW4McQd7CbVtyjqoe9mw    5.0       2      0     1
# 43          79  MTSW4McQd7CbVtyjqoe9mw    5.0       0      0     5
# 44          82  MTSW4McQd7CbVtyjqoe9mw    5.0       1      0     0
# 45          83  MTSW4McQd7CbVtyjqoe9mw    4.0       1      0     0
# 46          84  MTSW4McQd7CbVtyjqoe9mw    5.0      35     14    26
# 47          85  MTSW4McQd7CbVtyjqoe9mw    2.0       2      2     1
#
#                           DishInText
# 0                           {'rice'}
# 1                           {'rice'}
# 2                {'english', 'rice'}
# 3                          {'bread'}
# 4                           {'rice'}
# 5              {'chocolate', 'rice'}
# 6                          {'bread'}
# 7            {'soy milk', 'hot dog'}
# 8                           {'rice'}
# 9                        {'english'}
# 10                          {'rice'}
# 11             {'chocolate', 'rice'}
# 12                         {'bread'}
# 13                         {'bread'}
# 14   {'chocolate', 'curry', 'bread'}
# 15             {'croissant', 'rice'}
# 16                   {'rice', 'dal'}
# 17               {'rice', 'hot dog'}
# 18                          {'rice'}
# 19                         {'curry'}
# 20                          {'rice'}
# 21                          {'rice'}
# 22                          {'pita'}
# 23  {'english', 'rice', 'chocolate'}
# 24                       {'english'}
# 25                          {'rice'}
# 26               {'english', 'rice'}
# 27                          {'rice'}
# 28                         {'ploye'}
# 29                         {'bread'}
# 30                       {'english'}
# 31             {'rice', 'dumplings'}
# 32             {'char siu', 'bread'}
# 33                     {'dumplings'}
# 34                          {'rice'}
# 35                         {'bread'}
# 36                         {'bread'}
# 37                     {'taro cake'}
# 38                          {'rice'}
# 39                         {'bread'}
# 40                          {'rice'}
# 41                         {'bread'}
# 42                          {'rice'}
# 43                         {'swiss'}
# 44              {'mooncake', 'rice'}
# 45                {'baozi', 'bread'}
# 46                          {'rice'}
# 47                          {'rice'}

# %%
data['weight'] = 1 + (data['useful'] + 0.5 * data['funny'] + 0.5 * data['cool'])**(1/3)

# %%
data['weight'].hist()

# %%
data['weighted_score'] = (data['stars'] - 3) * data['weight']

# %%
data['weighted_score'].hist()

# %%
all_business = set(data['business_id'])
new_data = data.loc[:1, :]

# %%
new_data
# Out:
#    Unnamed: 0             business_id  stars  useful  funny  cool DishInText  \
# 0           0  MTSW4McQd7CbVtyjqoe9mw    4.0       0      0     1   {'rice'}
# 1           1  MTSW4McQd7CbVtyjqoe9mw    4.0       3      1     2   {'rice'}
#
#      weight  weighted_score
# 0  1.793701        1.793701
# 1  2.650964        2.650964

# %%
import re

# %%
len(data)
# Out:
# 2445694

# %%
for idx in range(len(data)):
    temp = set((re.findall(r"'(.*?)'", data.at[idx, 'DishInText'])))
    while temp:
        dish = temp.pop()
        temp_dict = {'business_id': data.at[idx,'business_id'], 
                     'weighted_score': data.at[idx,'weighted_score'], 
                     'DishInText': dish}
        new_data.append(temp_dict, ignore_index = True)
    if idx % 10000 == 0:
        print(idx)
# Out:
# 0
# 10000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-e08de5d04372> in <module>
#       6                      'weighted_score': data.at[idx,'weighted_score'],
#       7                      'DishInText': dish}
# ----> 8         new_data.append(temp_dict, ignore_index = True)
#       9     if idx % 10000 == 0:
#      10         print(idx)
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7116                 other.values.reshape((1, len(other))),
#    7117                 index=index,
# -> 7118                 columns=combined_columns,
#    7119             )
#    7120             other = other._convert(datetime=True, timedelta=True)
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     438                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     439             else:
# --> 440                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     441
#     442         # For data is list-like, or Iterable (will consume into list)
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     211         block_values = [values]
#     212
# --> 213     return create_block_manager_from_blocks(block_values, [columns, index])
#     214
#     215
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679                 ]
#    1680
# -> 1681         mgr = BlockManager(blocks, axes)
#    1682         mgr._consolidate_inplace()
#    1683         return mgr
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     145         self._consolidate_check()
#     146
# --> 147         self._rebuild_blknos_and_blklocs()
#     148
#     149     def make_empty(self, axes=None):
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     226             rl = blk.mgr_locs
#     227             new_blknos[rl.indexer] = blkno
# --> 228             new_blklocs[rl.indexer] = np.arange(len(rl))
#     229
#     230         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
new_data

# %%
new_data = new_data.loc[2: , ['business_id', 'weighted_score', 'DishInText']]

# %%
buz_dict = {}
for buz_id in all_business:
    dish_dict = {}
    dish_candidate = set(data.loc[data['business_id'] == buz_id, 'DishInText'])
    for dish in dish_candidate:
        score = data.loc[(data['business_id'] == buz_id) & (data['DishInText'] == dish), 'weighted_score']
        dish_dict[dish] = (score.mean(), score.sum())
    buz_dict[buz_id] = dish_dict
# Out:
# {'rice'}{'ice cream'}{'birria'}{'tacos', 'elote', 'birria'}{'elote'}{'fresas con crema', 'ice cream'}{'tacos', 'ice cream', 'birria'}{'birria'}{'elote'}{'chocolate', 'rice'}{'elote'}{'ploye'}{'rice'}{'nachos'}{'ploye', 'birria'}{'ploye'}{'ice cream'}{'birria'}{'nachos', 'chamoy'}{'nachos', 'birria'}{'ploye'}{'ice cream'}{'tacos', 'elote', 'birria'}{'gur'}{'rice'}{'ploye'}{'chamoy'}{'ice cream'}{'rice'}{'ice cream'}
# ['rice', 'ice cream', 'birria', 'tacos', 'elote', 'birria', 'elote', 'fresas con crema', 'ice cream', 'tacos', 'ice cream', 'birria', 'birria', 'elote', 'chocolate', 'rice', 'elote', 'ploye', 'rice', 'nachos', 'ploye', 'birria', 'ploye', 'ice cream', 'birria', 'nachos', 'chamoy', 'nachos', 'birria', 'ploye', 'ice cream', 'tacos', 'elote', 'birria', 'gur', 'rice', 'ploye', 'chamoy', 'ice cream', 'rice', 'ice cream']
