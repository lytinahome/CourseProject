# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./business.csv")

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'business_id',
#  'name',
#  'address',
#  'city',
#  'state',
#  'postal_code',
#  'latitude',
#  'longitude',
#  'stars',
#  'review_count',
#  'is_open',
#  'attributes',
#  'categories',
#  'hours']

# %%
df.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# ...

# %%
df["categories"].unique().tolist()
# Out:
# ['Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists',
#  'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services',
#  'Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores',
#  'Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries',
#  'Brewpubs, Breweries, Food',
#  'Burgers, Fast Food, Sandwiches, Food, Ice Cream & Frozen Yogurt, Restaurants',
#  'Sporting Goods, Fashion, Shoe Stores, Shopping, Sports Wear, Accessories',
#  'Synagogues, Religious Organizations',
#  'Pubs, Restaurants, Italian, Bars, American (Traditional), Nightlife, Greek',
#  'Ice Cream & Frozen Yogurt, Fast Food, Burgers, Restaurants, Food',
#  'Department Stores, Shopping, Fashion',
#  'Vietnamese, Food, Restaurants, Food Trucks',
#  'American (Traditional), Restaurants, Diners, Breakfast & Brunch',
#  'General Dentistry, Dentists, Health & Medical, Cosmetic Dentists',
# ...

# %%
restaurant_id = []
for item in df["categories"].unique().tolist():
    if isinstance(item, str):
        if ("Restaurants" in item) or ("Food" in item):
            restaurants.append(item)

# %%
restaurant_id = []
for idx, item in df.iterrows():
    if (isinstance(item["categories"], str)):
        if ("Restaurants" in item["categories"]) or ("Food" in item["categories"]):
            restaurant_id.append(item["business_id"])

# %%
review = pd.read_csv("./review.csv")

# %%
#review["business_id"] = review["business_id"].astype('str')
review["business_id"] = review["business_id"].apply(lambda x: str(x, 'utf-8'))
type(review["business_id"].iat[0])
#review["business_id"].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-2bc1e4c1f624> in <module>
#       1 #review["business_id"] = review["business_id"].astype('str')
# ----> 2 review["business_id"] = review["business_id"].apply(lambda x: str(x, 'utf-8'))
#       3 type(review["business_id"].iat[0])
#       4 #review["business_id"].head()
#
# D:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-78-2bc1e4c1f624> in <lambda>(x)
#       1 #review["business_id"] = review["business_id"].astype('str')
# ...

# %%
b'XQfwVwDr-v0ZS3_CbbE5Xw' in review["business_id"]
# Out:
# False

# %%
review.head()
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1           1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2           2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3           3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4           4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#                  business_id  stars  useful  funny  cool  \
# 0  b'XQfwVwDr-v0ZS3_CbbE5Xw'    3.0       0      0     0
# 1  b'7ATYjTIgM3jUlt4UM3IypQ'    5.0       1      0     1
# 2  b'YjUWPpI6HXG530lwP-fb2A'    3.0       0      0     0
# 3  b'kxX2SOes4o-D3ZQBkiMRfA'    5.0       1      0     1
# 4  b'e4Vwtrqf-wpJfwesgvdgxQ'    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# ...

# %%
len(restaurant_id)
restaurant_id
# Out:
# ['MTSW4McQd7CbVtyjqoe9mw',
#  'mWMc6_wTdE0EUBKIGXDVfA',
#  'CF33F8-E6oudUQ46HnavjQ',
#  'k0hlBqXX-Bt0vf1op7Jr1w',
#  'bBDDEgkFA1Otx9Lfe7BZUQ',
#  'eEOYSgkmpB90uNA7lDOMRA',
#  'il_Ro8jwPlHresjw9EGmBg',
#  '0bPLkL0QhhPO5kt1_EXmNQ',
#  'MUTTqe8uqyMdBl186RmNeA',
#  'ROeacJQwBeh05Rqg7F6TCg',
#  'WKMJwqnfZKsAae75RMP6jA',
#  'kfNv-JZpuN6TVNSO6hHdkw',
#  '9OG5YkX1g2GReZM0AskizA',
#  '4iRzR7OaS-QaSXuvYxEGKA',
#  'tMkwHmWFUEXrC9ZduonpTg',
#  'QdN72BWoyFypdGJhhI5r7g',
#  'sqSqqLy0sN8n2IZrAbzidQ',
#  'Mjboz24M9NlBeiOJKLEd_Q',
#  'kV_Q1oqis8Qli8dUoGpTyQ',
#  'aPNXGTDkf-4bjhyMBQxqpQ',
#  '2xVsWBNFwZOxIOdd9Mwnww',
#  'ljxNT9p0y7YMPx0fcNBGig',
#  'wghnIlMb_i5U46HMBGx9ig',
#  'JX4tUpd09YFchLBuI43lGw',
#  'lk9IwjZXqUMqqOhM774DtQ',
#  'ABxoFuzZy5mqQ8C5FJJajQ',
#  '5BmQX4UVJY19mMtafMg7JA',
#  'cVBxfMC4lp3DnocjYA3FHQ',
#  '0qNpTGTcqPwOLi2hADx4Xw',
#  'txyXRytGjwOXvS8s4sc-WA',
#  'uI9XODGY_2_ieTE6xJ0myw',
#  'JgpnXv_0XhV3SfbfB50nxw',
#  'Si6LXSR9gvAbmgO5DzV2cw',
#  'seKihQKpGGnCeLuELRQPSQ',
# ...

# %%
idx = review["business_id"].isin(df["business_id"])
idx.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-5a0a109a3907> in <module>
# ----> 1 idx = review["business_id"].decode("utf-8").isin(df["business_id"])
#       2 idx.sum()
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'decode'

# %%
review["business_id"].head()
# Out:
# 0    b'XQfwVwDr-v0ZS3_CbbE5Xw'
# 1    b'7ATYjTIgM3jUlt4UM3IypQ'
# 2    b'YjUWPpI6HXG530lwP-fb2A'
# 3    b'kxX2SOes4o-D3ZQBkiMRfA'
# 4    b'e4Vwtrqf-wpJfwesgvdgxQ'
# Name: business_id, dtype: object

# %%
a = review["business_id"]
b = df["business_id"]
temp = set(a).intersection(b)

# %%
temp
# Out:
# set()

# %%
related_review = review[idx]

# %%
related_review
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, review_id, user_id, business_id, stars, useful, funny, cool, text, date]
# Index: []

# %%
review.shape
# Out:
# (6990280, 10)

# %%
len('XQfwVwDr-v0ZS3_CbbE5Xw')
# Out:
# 22

# %%
len('JX4tUpd09YFchLBuI43lGw')
# Out:
# 22
